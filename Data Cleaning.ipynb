# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\AKSHAT\Desktop\E-Com Project\messy_ecommerce_sales_data.csv")

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)



df
# Out:
#       ID  Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100   Customer_100  ORD-41285  11/22/2024        Blender         Home
# 1    101   Customer_101  ORD-35783    7/5/2025     Smartphone  Electronics
# 2    102   Customer_102  ORD-84355  12/23/2024  Tennis Racket       Sports
# 3    103   Customer_103  ORD-57811   3/19/2025        Science        Books
# 4    104   Customer_104  ORD-93614  10/20/2025      Biography        Books
# 5    105   Customer_105  ORD-22442  11/20/2024  Tennis Racket       Sports
# 6    106   Customer_106  ORD-25885    2/2/2025        Blender         Home
# 7    107   Customer_107  ORD-89122    1/3/2025      Biography        Books
# 8    108   Customer_108  ORD-64400  10/23/2025        Science        Books
# 9    109   Customer_109  ORD-18512    5/3/2025  Tennis Racket       Sports
# 10   110   Customer_110  ORD-61020   9/26/2025     Basketball       sports
# ...

# %%
df.shape
# Out:
# (103, 11)

# %%
df.columns
# Out:
# Index(['ID', ' Customer_Name', 'Order_ID', 'Order_Date', 'Product',
#        ' Category', 'Quantity', 'Price', 'Payment_Method', 'Status', 'Total'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                  int64
#  Customer_Name     object
# Order_ID           object
# Order_Date         object
# Product            object
#  Category          object
# Quantity           object
# Price              object
# Payment_Method     object
# Status             object
# Total             float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              103 non-null    int64
#  1    Customer_Name  103 non-null    object
#  2   Order_ID        103 non-null    object
#  3   Order_Date      103 non-null    object
#  4   Product         103 non-null    object
#  5    Category       95 non-null     object
#  6   Quantity        98 non-null     object
#  7   Price           98 non-null     object
#  8   Payment_Method  103 non-null    object
#  9   Status          103 non-null    object
#  10  Total           89 non-null     float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 9.0+ KB

# %%
df.isnull().sum()
# Out:
# ID                 0
#  Customer_Name     0
# Order_ID           0
# Order_Date         0
# Product            0
#  Category          8
# Quantity           5
# Price              5
# Payment_Method     0
# Status             0
# Total             14
# dtype: int64

# %%
# cleaning Column Names 
df.columns = df.columns.str.strip()
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        Blender         Home
# 1    101  Customer_101  ORD-35783    7/5/2025     Smartphone  Electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  Tennis Racket       Sports
# 3    103  Customer_103  ORD-57811   3/19/2025        Science        Books
# 4    104  Customer_104  ORD-93614  10/20/2025      Biography        Books
# 5    105  Customer_105  ORD-22442  11/20/2024  Tennis Racket       Sports
# 6    106  Customer_106  ORD-25885    2/2/2025        Blender         Home
# 7    107  Customer_107  ORD-89122    1/3/2025      Biography        Books
# 8    108  Customer_108  ORD-64400  10/23/2025        Science        Books
# 9    109  Customer_109  ORD-18512    5/3/2025  Tennis Racket       Sports
# 10   110  Customer_110  ORD-61020   9/26/2025     Basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         Comics        Books
# ...

# %%
# Stripping Extra Spaces from The Category Column
df["Category"] = df["Category"].str.strip() 
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        Blender         Home
# 1    101  Customer_101  ORD-35783    7/5/2025     Smartphone  Electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  Tennis Racket       Sports
# 3    103  Customer_103  ORD-57811   3/19/2025        Science        Books
# 4    104  Customer_104  ORD-93614  10/20/2025      Biography        Books
# 5    105  Customer_105  ORD-22442  11/20/2024  Tennis Racket       Sports
# 6    106  Customer_106  ORD-25885    2/2/2025        Blender         Home
# 7    107  Customer_107  ORD-89122    1/3/2025      Biography        Books
# 8    108  Customer_108  ORD-64400  10/23/2025        Science        Books
# 9    109  Customer_109  ORD-18512    5/3/2025  Tennis Racket       Sports
# 10   110  Customer_110  ORD-61020   9/26/2025     Basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         Comics        Books
# ...

# %%
#Keeping All Letter to Lowercase
df["Category"] = df["Category"].str.lower()
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        Blender         home
# 1    101  Customer_101  ORD-35783    7/5/2025     Smartphone  electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  Tennis Racket       sports
# 3    103  Customer_103  ORD-57811   3/19/2025        Science        books
# 4    104  Customer_104  ORD-93614  10/20/2025      Biography        books
# 5    105  Customer_105  ORD-22442  11/20/2024  Tennis Racket       sports
# 6    106  Customer_106  ORD-25885    2/2/2025        Blender         home
# 7    107  Customer_107  ORD-89122    1/3/2025      Biography        books
# 8    108  Customer_108  ORD-64400  10/23/2025        Science        books
# 9    109  Customer_109  ORD-18512    5/3/2025  Tennis Racket       sports
# 10   110  Customer_110  ORD-61020   9/26/2025     Basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         Comics        books
# ...

# %%
df["Product"] = df["Product"].str.strip()
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        Blender         home
# 1    101  Customer_101  ORD-35783    7/5/2025     Smartphone  electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  Tennis Racket       sports
# 3    103  Customer_103  ORD-57811   3/19/2025        Science        books
# 4    104  Customer_104  ORD-93614  10/20/2025      Biography        books
# 5    105  Customer_105  ORD-22442  11/20/2024  Tennis Racket       sports
# 6    106  Customer_106  ORD-25885    2/2/2025        Blender         home
# 7    107  Customer_107  ORD-89122    1/3/2025      Biography        books
# 8    108  Customer_108  ORD-64400  10/23/2025        Science        books
# 9    109  Customer_109  ORD-18512    5/3/2025  Tennis Racket       sports
# 10   110  Customer_110  ORD-61020   9/26/2025     Basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         Comics        books
# ...

# %%
df["Product"] = df["Product"].str.lower()
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        blender         home
# 1    101  Customer_101  ORD-35783    7/5/2025     smartphone  electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  tennis racket       sports
# 3    103  Customer_103  ORD-57811   3/19/2025        science        books
# 4    104  Customer_104  ORD-93614  10/20/2025      biography        books
# 5    105  Customer_105  ORD-22442  11/20/2024  tennis racket       sports
# 6    106  Customer_106  ORD-25885    2/2/2025        blender         home
# 7    107  Customer_107  ORD-89122    1/3/2025      biography        books
# 8    108  Customer_108  ORD-64400  10/23/2025        science        books
# 9    109  Customer_109  ORD-18512    5/3/2025  tennis racket       sports
# 10   110  Customer_110  ORD-61020   9/26/2025     basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         comics        books
# ...

# %%
df["Category"]= df["Category"].replace("electronic", "electronics")
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        blender         home
# 1    101  Customer_101  ORD-35783    7/5/2025     smartphone  electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  tennis racket       sports
# 3    103  Customer_103  ORD-57811   3/19/2025        science        books
# 4    104  Customer_104  ORD-93614  10/20/2025      biography        books
# 5    105  Customer_105  ORD-22442  11/20/2024  tennis racket       sports
# 6    106  Customer_106  ORD-25885    2/2/2025        blender         home
# 7    107  Customer_107  ORD-89122    1/3/2025      biography        books
# 8    108  Customer_108  ORD-64400  10/23/2025        science        books
# 9    109  Customer_109  ORD-18512    5/3/2025  tennis racket       sports
# 10   110  Customer_110  ORD-61020   9/26/2025     basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         comics        books
# ...

# %%
df["Category"].unique()
# Out:
# array(['home', 'electronics', 'sports', 'books', 'clothing', nan],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# ID                 0
# Customer_Name      0
# Order_ID           0
# Order_Date         0
# Product            0
# Category           8
# Quantity           5
# Price              5
# Payment_Method     0
# Status             0
# Total             14
# dtype: int64

# %%
df["Quantity"].unique()
# Out:
# array(['3', '2', '1', '5', nan, '4', '-2', '-5', '4a'], dtype=object)

# %%
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        blender         home
# 1    101  Customer_101  ORD-35783    7/5/2025     smartphone  electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  tennis racket       sports
# 3    103  Customer_103  ORD-57811   3/19/2025        science        books
# 4    104  Customer_104  ORD-93614  10/20/2025      biography        books
# 5    105  Customer_105  ORD-22442  11/20/2024  tennis racket       sports
# 6    106  Customer_106  ORD-25885    2/2/2025        blender         home
# 7    107  Customer_107  ORD-89122    1/3/2025      biography        books
# 8    108  Customer_108  ORD-64400  10/23/2025        science        books
# 9    109  Customer_109  ORD-18512    5/3/2025  tennis racket       sports
# 10   110  Customer_110  ORD-61020   9/26/2025     basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         comics        books
# ...

# %%
df["Quantity"] = pd.to_numeric(df["Quantity"], errors="coerce")
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        blender         home
# 1    101  Customer_101  ORD-35783    7/5/2025     smartphone  electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  tennis racket       sports
# 3    103  Customer_103  ORD-57811   3/19/2025        science        books
# 4    104  Customer_104  ORD-93614  10/20/2025      biography        books
# 5    105  Customer_105  ORD-22442  11/20/2024  tennis racket       sports
# 6    106  Customer_106  ORD-25885    2/2/2025        blender         home
# 7    107  Customer_107  ORD-89122    1/3/2025      biography        books
# 8    108  Customer_108  ORD-64400  10/23/2025        science        books
# 9    109  Customer_109  ORD-18512    5/3/2025  tennis racket       sports
# 10   110  Customer_110  ORD-61020   9/26/2025     basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         comics        books
# ...

# %%
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        blender         home
# 1    101  Customer_101  ORD-35783    7/5/2025     smartphone  electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  tennis racket       sports
# 3    103  Customer_103  ORD-57811   3/19/2025        science        books
# 4    104  Customer_104  ORD-93614  10/20/2025      biography        books
# 5    105  Customer_105  ORD-22442  11/20/2024  tennis racket       sports
# 6    106  Customer_106  ORD-25885    2/2/2025        blender         home
# 7    107  Customer_107  ORD-89122    1/3/2025      biography        books
# 8    108  Customer_108  ORD-64400  10/23/2025        science        books
# 9    109  Customer_109  ORD-18512    5/3/2025  tennis racket       sports
# 10   110  Customer_110  ORD-61020   9/26/2025     basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         comics        books
# ...

# %%
df[df["Quantity"]<0]
# Out:
#      ID Customer_Name   Order_ID Order_Date  Product     Category  Quantity  \
# 17  117  Customer_117  ORD-72751  2/12/2025  blender  electronics      -2.0
# 34  134  Customer_134  ORD-16585  10/4/2025  t-shirt     clothing      -5.0
#
#      Price    Payment_Method      Status     Total
# 17   10000  Cash on Delivery  Processing -20000.00
# 34  591.53            PayPal     Shipped  -2957.65

# %%
df.loc[df["Quantity"]<0, "Quantity"]= np.nan
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        blender         home
# 1    101  Customer_101  ORD-35783    7/5/2025     smartphone  electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  tennis racket       sports
# 3    103  Customer_103  ORD-57811   3/19/2025        science        books
# 4    104  Customer_104  ORD-93614  10/20/2025      biography        books
# 5    105  Customer_105  ORD-22442  11/20/2024  tennis racket       sports
# 6    106  Customer_106  ORD-25885    2/2/2025        blender         home
# 7    107  Customer_107  ORD-89122    1/3/2025      biography        books
# 8    108  Customer_108  ORD-64400  10/23/2025        science        books
# 9    109  Customer_109  ORD-18512    5/3/2025  tennis racket       sports
# 10   110  Customer_110  ORD-61020   9/26/2025     basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         comics        books
# ...

# %%
df["Quantity"].unique()
# Out:
# array([ 3.,  2.,  1.,  5., nan,  4.])

# %%
df["Quantity"]= df["Quantity"].fillna(df["Quantity"].median())
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        blender         home
# 1    101  Customer_101  ORD-35783    7/5/2025     smartphone  electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  tennis racket       sports
# 3    103  Customer_103  ORD-57811   3/19/2025        science        books
# 4    104  Customer_104  ORD-93614  10/20/2025      biography        books
# 5    105  Customer_105  ORD-22442  11/20/2024  tennis racket       sports
# 6    106  Customer_106  ORD-25885    2/2/2025        blender         home
# 7    107  Customer_107  ORD-89122    1/3/2025      biography        books
# 8    108  Customer_108  ORD-64400  10/23/2025        science        books
# 9    109  Customer_109  ORD-18512    5/3/2025  tennis racket       sports
# 10   110  Customer_110  ORD-61020   9/26/2025     basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         comics        books
# ...

# %%
df["Quantity"] = df["Quantity"].round().astype(int)
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        blender         home
# 1    101  Customer_101  ORD-35783    7/5/2025     smartphone  electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  tennis racket       sports
# 3    103  Customer_103  ORD-57811   3/19/2025        science        books
# 4    104  Customer_104  ORD-93614  10/20/2025      biography        books
# 5    105  Customer_105  ORD-22442  11/20/2024  tennis racket       sports
# 6    106  Customer_106  ORD-25885    2/2/2025        blender         home
# 7    107  Customer_107  ORD-89122    1/3/2025      biography        books
# 8    108  Customer_108  ORD-64400  10/23/2025        science        books
# 9    109  Customer_109  ORD-18512    5/3/2025  tennis racket       sports
# 10   110  Customer_110  ORD-61020   9/26/2025     basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         comics        books
# ...

# %%
df["Price"] = df["Price"].astype(str).str.strip()

# %%
df["Price"].unique()
# Out:
# array(['38', 'abd', '389.05', '233.92', '552.51', '122.06', '978.63',
#        '587.68', '600.29', '168.34', 'four hundred', '865.77', '752.13',
#        '411.81', '413.13', '796.84', 'nan', '10000', '247.82', '438.19',
#        '300$', '523.01', '556.93', '615.91', '765.69', '836.8', '336.02',
#        '898.69', '736.71', '616.63', '266.7', '343.24', '591.53',
#        '446.19', '696.71', '-100', '531.06', '681.38', '588.98', '546.04',
#        '645.26', '826.77', '849.07', '860.99', '705.42', '596.15',
#        '660.98', '896.38', '206.19', '457.16', '233.11', '278.9',
#        '789.64', '40.95', '275.1', '933.58', '163.16', '242.52', '209.32',
#        '155.76', '235.26', '587.64', '443.13', '569.38', '593.93',
#        '141.49', '582.13', '741.63', '688.68', '942.76', '351.89',
#        '187.48', '111.36', '530.52', '69.48', '472.14', '868.67',
#        '418.38', '266.48', '538.35', '101.19', '730.92', '365.34',
# ...

# %%
df["Price"] = df["Price"].str.replace('$','',regex=False)
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        blender         home
# 1    101  Customer_101  ORD-35783    7/5/2025     smartphone  electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  tennis racket       sports
# 3    103  Customer_103  ORD-57811   3/19/2025        science        books
# 4    104  Customer_104  ORD-93614  10/20/2025      biography        books
# 5    105  Customer_105  ORD-22442  11/20/2024  tennis racket       sports
# 6    106  Customer_106  ORD-25885    2/2/2025        blender         home
# 7    107  Customer_107  ORD-89122    1/3/2025      biography        books
# 8    108  Customer_108  ORD-64400  10/23/2025        science        books
# 9    109  Customer_109  ORD-18512    5/3/2025  tennis racket       sports
# 10   110  Customer_110  ORD-61020   9/26/2025     basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         comics        books
# ...

# %%
df["Price"]= pd.to_numeric(df["Price"],errors="coerce")
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        blender         home
# 1    101  Customer_101  ORD-35783    7/5/2025     smartphone  electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  tennis racket       sports
# 3    103  Customer_103  ORD-57811   3/19/2025        science        books
# 4    104  Customer_104  ORD-93614  10/20/2025      biography        books
# 5    105  Customer_105  ORD-22442  11/20/2024  tennis racket       sports
# 6    106  Customer_106  ORD-25885    2/2/2025        blender         home
# 7    107  Customer_107  ORD-89122    1/3/2025      biography        books
# 8    108  Customer_108  ORD-64400  10/23/2025        science        books
# 9    109  Customer_109  ORD-18512    5/3/2025  tennis racket       sports
# 10   110  Customer_110  ORD-61020   9/26/2025     basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         comics        books
# ...

# %%
df.loc[df["Price"] <= 0, "Price"] = np.nan
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        blender         home
# 1    101  Customer_101  ORD-35783    7/5/2025     smartphone  electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  tennis racket       sports
# 3    103  Customer_103  ORD-57811   3/19/2025        science        books
# 4    104  Customer_104  ORD-93614  10/20/2025      biography        books
# 5    105  Customer_105  ORD-22442  11/20/2024  tennis racket       sports
# 6    106  Customer_106  ORD-25885    2/2/2025        blender         home
# 7    107  Customer_107  ORD-89122    1/3/2025      biography        books
# 8    108  Customer_108  ORD-64400  10/23/2025        science        books
# 9    109  Customer_109  ORD-18512    5/3/2025  tennis racket       sports
# 10   110  Customer_110  ORD-61020   9/26/2025     basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         comics        books
# ...

# %%
df["Price"] = df["Price"].fillna(df["Price"].median())
df
# Out:
#       ID Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285  11/22/2024        blender         home
# 1    101  Customer_101  ORD-35783    7/5/2025     smartphone  electronics
# 2    102  Customer_102  ORD-84355  12/23/2024  tennis racket       sports
# 3    103  Customer_103  ORD-57811   3/19/2025        science        books
# 4    104  Customer_104  ORD-93614  10/20/2025      biography        books
# 5    105  Customer_105  ORD-22442  11/20/2024  tennis racket       sports
# 6    106  Customer_106  ORD-25885    2/2/2025        blender         home
# 7    107  Customer_107  ORD-89122    1/3/2025      biography        books
# 8    108  Customer_108  ORD-64400  10/23/2025        science        books
# 9    109  Customer_109  ORD-18512    5/3/2025  tennis racket       sports
# 10   110  Customer_110  ORD-61020   9/26/2025     basketball       sports
# 11   111  Customer_111  ORD-72349  10/22/2025         comics        books
# ...

# %%
df["Order_Date"]= pd.to_datetime(df["Order_Date"],errors="coerce")

# %%
df[df["Order_Date"].isnull()]
# Out:
#      ID Customer_Name   Order_ID Order_Date     Product     Category  \
# 14  114  Customer_114  ORD-77417        NaT  smartphone  electronics
# 92  192  Customer_192  ORD-35144        NaT      jacket     clothing
#
#     Quantity   Price    Payment_Method    Status   Total
# 14         2  413.13  Cash on Delivery   Shipped  826.26
# 92         3  203.63       Credit Card  Returned     NaN

# %%
df = df.dropna(subset="Order_Date")

# %%
df2 = df.copy()
df2
# Out:
#       ID Customer_Name   Order_ID Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285 2024-11-22        blender         home
# 1    101  Customer_101  ORD-35783 2025-07-05     smartphone  electronics
# 2    102  Customer_102  ORD-84355 2024-12-23  tennis racket       sports
# 3    103  Customer_103  ORD-57811 2025-03-19        science        books
# 4    104  Customer_104  ORD-93614 2025-10-20      biography        books
# 5    105  Customer_105  ORD-22442 2024-11-20  tennis racket       sports
# 6    106  Customer_106  ORD-25885 2025-02-02        blender         home
# 7    107  Customer_107  ORD-89122 2025-01-03      biography        books
# 8    108  Customer_108  ORD-64400 2025-10-23        science        books
# 9    109  Customer_109  ORD-18512 2025-05-03  tennis racket       sports
# 10   110  Customer_110  ORD-61020 2025-09-26     basketball       sports
# 11   111  Customer_111  ORD-72349 2025-10-22         comics        books
# ...

# %%
df2["Payment_Method"]= df2["Payment_Method"].str.strip()

# %%
df2["Status"]=df["Status"].str.strip()

# %%
df2["Product"] = df2["Product"].str.strip()

# %%
df2["Order_ID"] = df2["Order_ID"].astype(str).str.strip()

# %%
df2["Order_ID"].duplicated().sum()
# Out:
# np.int64(2)

# %%
df2["Order_ID"]=df2["Order_ID"].drop_duplicates()

# %%
df2["Total"] = df["Quantity"] * df2["Price"]

# %%
df2.groupby("Category")["Total"].sum()
# Out:
# Category
# books          41068.08
# clothing       32698.52
# electronics    51920.53
# home           33087.54
# sports         25076.32
# Name: Total, dtype: float64

# %%
df2["Total"] = df2["Total"].round(2)

# %%
df2.dtypes
# Out:
# ID                         int64
# Customer_Name             object
# Order_ID                  object
# Order_Date        datetime64[ns]
# Product                   object
# Category                  object
# Quantity                   int64
# Price                    float64
# Payment_Method            object
# Status                    object
# Total                    float64
# dtype: object

# %%
df2.isnull().sum()
# Out:
# ID                0
# Customer_Name     0
# Order_ID          3
# Order_Date        0
# Product           0
# Category          8
# Quantity          0
# Price             0
# Payment_Method    0
# Status            0
# Total             0
# dtype: int64

# %%
print("Negative quantities:", (df["Quantity"] < 0).sum())
print("Negative prices:", (df["Price"] < 0).sum())
print("Negative totals:", (df["Total"] < 0).sum())
# Out:
# Negative quantities: 0
# Negative prices: 0
# Negative totals: 0

# %%
product_category = {
    "Blender": "home",
    "Microwave": "home",
    "Lamp": "home",
    "vacuum": "home",
    "smartphone": "electronics",
    "Smartwatch": "electronics",
    "laptop": "electronics",
    "headphones": "electronics",
    "basketball": "sports",
    "Tennis Racket": "sports",
    "Yoga Mat": "sports",
    "Football": "sports",
    "biography": "books",
    "Science": "books",
    "Comics": "books",
    "Fiction": "books",
    "shoes": "clothing",
    "T-shirt": "clothing",
    "Jacket": "clothing",
    "Jeans": "clothing"
}

# %%
df2["Category"]= df2["Category"].fillna(df2["Product"].map(product_category))

# %% [markdown]
# # Final Cleaned Dataset

# %%
df2
# Out:
#       ID Customer_Name   Order_ID Order_Date        Product     Category  \
# 0    100  Customer_100  ORD-41285 2024-11-22        blender         home
# 1    101  Customer_101  ORD-35783 2025-07-05     smartphone  electronics
# 2    102  Customer_102  ORD-84355 2024-12-23  tennis racket       sports
# 3    103  Customer_103  ORD-57811 2025-03-19        science        books
# 4    104  Customer_104  ORD-93614 2025-10-20      biography        books
# 5    105  Customer_105  ORD-22442 2024-11-20  tennis racket       sports
# 6    106  Customer_106  ORD-25885 2025-02-02        blender         home
# 7    107  Customer_107  ORD-89122 2025-01-03      biography        books
# 8    108  Customer_108  ORD-64400 2025-10-23        science        books
# 9    109  Customer_109  ORD-18512 2025-05-03  tennis racket       sports
# 10   110  Customer_110  ORD-61020 2025-09-26     basketball       sports
# 11   111  Customer_111  ORD-72349 2025-10-22         comics        books
# ...
